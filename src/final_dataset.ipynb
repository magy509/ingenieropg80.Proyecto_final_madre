# %%
##! pip install -r ../requirements.txt

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import datasets as ds
import math



import pickle

# %%
movies = ds.peli_info_df()

# %%
movielens_df = movies[1]

movielens_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 87580   292731           The Monroy Affaire (2022)
# 87581   292737          Shelter in Solitude (2023)
# 87582   292753                         Orca (2023)
# 87583   292755              The Angry Breed (1968)
# 87584   292757           Race to the Summit (2023)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
link1 = "../data/processed/reviews_comentarios.csv"
link2 = "../data/processed/reviews_sentimiento.csv"
amazon_df = pd.read_csv(link1)

amazon_df
# Out:
#         productId          userId                                 profileName  \
# 0      B003AI2VGA  A141HP4LYPWMSR            Brian E. Erland "Rainbow Sphinx"
# 1      B003AI2VGA  A328S9RN3U5M68                                  Grady Harp
# 2      B003AI2VGA  A1I7QGUDP043DG                   Chrissy K. McVay "Writer"
# 3      B003AI2VGA  A1M5405JH9THP9                                golgotha.gov
# 4      B003AI2VGA   ATXL536YX71TR  KerrLines "&#34;Movies,Music,Theatre&#34;"
# ...           ...             ...                                         ...
# 49963  B001QVG86C  A1WDFSICN421XU                     Barbara Daddario "Barb"
# 49964  B001QVG86C   A8TYY6R6ZSMNX                                 Glenn Jones
# 49965  B001QVG86C  A1TKXLT6ZAULHS                         genie178 "genie178"
# 49966  B001QVG86C   AGUAHW8ZE19C6                         My name is Mike "M"
# 49967  B001QVG86C   AZKZS5WMNJOH3                              Barbara Ziemba
#
# ...

# %%
import pandas as pd
import random

# Tus datasets
# amazon_df = pd.read_csv("amazon.csv")
# movies_df = pd.read_csv("movies.csv")

# Obtener listas únicas
unique_product_ids = amazon_df['productId'].unique()
movie_ids = movielens_df['movieId'].tolist()

# Barajamos los movieIds para asignar aleatoriamente
random.shuffle(movie_ids)

# Creamos un diccionario de mapeo productId -> movieId
mapping = {pid: movie_ids[i % len(movie_ids)] for i, pid in enumerate(unique_product_ids)}

# Agregar la columna con movieId al dataset de Amazon
amazon_df['movieId'] = amazon_df['productId'].map(mapping)

# (opcional) guardarlo
# amazon_df.to_csv("amazon_mapped.csv", index=False)

print("Ejemplo de mapeo creado:")
print(amazon_df[['productId', 'movieId']].head(15))
# Out:
# Ejemplo de mapeo creado:
#      productId  movieId
# 0   B003AI2VGA     7283
# 1   B003AI2VGA     7283
# 2   B003AI2VGA     7283
# 3   B003AI2VGA     7283
# 4   B003AI2VGA     7283
# 5   B003AI2VGA     7283
# 6   B003AI2VGA     7283
# 7   B00006HAXW   184479
# 8   B00006HAXW   184479
# 9   B00006HAXW   184479
# 10  B00006HAXW   184479
# 11  B00006HAXW   184479
# 12  B00006HAXW   184479
# 13  B00006HAXW   184479
# 14  B00006HAXW   184479

# %%
amazon_df.head()
# Out:
#     productId          userId                                 profileName  \
# 0  B003AI2VGA  A141HP4LYPWMSR            Brian E. Erland "Rainbow Sphinx"
# 1  B003AI2VGA  A328S9RN3U5M68                                  Grady Harp
# 2  B003AI2VGA  A1I7QGUDP043DG                   Chrissy K. McVay "Writer"
# 3  B003AI2VGA  A1M5405JH9THP9                                golgotha.gov
# 4  B003AI2VGA   ATXL536YX71TR  KerrLines "&#34;Movies,Music,Theatre&#34;"
#
#   helpfulness  score        time  \
# 0         7/7    3.0  1182729600
# 1         4/4    3.0  1181952000
# 2        8/10    5.0  1164844800
# 3         1/1    3.0  1197158400
# 4         1/1    3.0  1188345600
#
#                                              summary  \
# 0  "There Is So Much Darkness Now ~ Come For The ...
# 1  Worthwhile and Important Story Hampered by Poo...
# 2                      This movie needed to be made.
# 3                  distantly based on a real tragedy
# ...

# %%
final_df = amazon_df[[
    "movieId",      
    "userId",       
    "text",         
    "score"         
]]

# Guardar en CSV
final_df.to_csv("../data/processed/reviews_clean.csv", index=False, encoding="utf-8")
